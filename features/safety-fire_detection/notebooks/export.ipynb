# %% [markdown]
# # Export & Optimize YOLOX Models
#
# Interactive notebook for exporting trained YOLOX models to ONNX,
# quantizing, and benchmarking all variants.

# %% [markdown]
# ## 1. Setup
#
# Configure paths and import dependencies. Change `CHECKPOINT_PATH` and config paths below for your model.
